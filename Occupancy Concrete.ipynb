# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt
plt.style.use("fivethirtyeight")

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch import optim
from stochastic_rnn import StochasticLSTM
from variational_module import MCSingleMixin
from classification_uncertainty_utils import aleatoric_uncertainty, epistemic_uncertainty, uncertainty_avg, score_avg
from train_utils import train_model, BCLogitMetric

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, precision_score
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split

# %%
np.random.seed(1234)
torch.manual_seed(1234)

# %%
training_table = pd.read_csv("./data/occupancy_data/datatraining.txt")

# %%
# training_table["year"] = training_table["date"].str[:4].astype(int) # only 2015
# training_table["month"] = training_table["date"].str[5:7].astype(int) # only February
training_table["day"] = training_table["date"].str[8:10].astype(int)
training_table["hour"] = training_table["date"].str[11:13].astype(int)

training_table["Temperature"] = training_table["Temperature"].astype(np.float32)
training_table["Humidity"] = training_table["Humidity"].astype(np.float32)
training_table["Light"] = training_table["Light"].astype(np.float32)
training_table["CO2"] = training_table["CO2"].astype(np.float32)
training_table["HumidityRatio"] = training_table["HumidityRatio"].astype(np.float32)
training_table["Occupancy"] = training_table["Occupancy"].astype(np.float32)

# %%
training_table = training_table.drop("date", axis=1)

# %%
training_table.head()
# Out:
#    Temperature   Humidity  Light     CO2  HumidityRatio  Occupancy  day  hour
# 1        23.18  27.271999  426.0  721.25       0.004793        1.0    4    17
# 2        23.15  27.267500  429.5  714.00       0.004783        1.0    4    17
# 3        23.15  27.245001  426.0  713.50       0.004779        1.0    4    17
# 4        23.15  27.200001  426.0  708.25       0.004772        1.0    4    17
# 5        23.10  27.200001  426.0  704.50       0.004757        1.0    4    17

# %%
plt.subplots(figsize=(6, 6))
sns.heatmap(training_table.corr(), annot=True, fmt=".0%")

# %%
training_table = training_table.drop("day", axis=1)
training_table = training_table.drop("hour", axis=1)

# %%
SEQ_LEN = 5
NUM_FEAT = 5

# %%
scaler = RobustScaler()

# %%
X_train = training_table.drop("Occupancy", axis=1).values
Y_train = training_table["Occupancy"].values
X_train = scaler.fit_transform(X_train, Y_train)
training_sequence = [(X_train[i:i+SEQ_LEN, :], Y_train[i+SEQ_LEN]) for i in range(0, len(X_train) - SEQ_LEN)]
N = len(Y_train)

# %%
train_set, test_set = train_test_split(training_sequence, test_size=0.3, shuffle=True)
train_dl = torch.utils.data.DataLoader(train_set, batch_size=200, shuffle=True, num_workers=2)
val_dl = torch.utils.data.DataLoader(test_set, batch_size=200, shuffle=True, num_workers=2)

# %%
class Net(nn.Module, MCSingleMixin):
    def __init__(self):
        super(Net, self).__init__()
        self.rnn = StochasticLSTM(NUM_FEAT, 50)
        self.fc1 = nn.Linear(50, 25)
        self.fc2 = nn.Linear(25, 1)
    
    def regularizer(self):        
        return 0.
    
    def get_output_shape(self, x: torch.Tensor):
        B = x.shape[1]
        return (B,)
    
    def forward(self, x):
        result, _ = self.rnn(x)
        result = torch.tanh(result[-1,:])
        result = torch.relu(self.fc1(result))
        result = self.fc2(result).flatten()
        return result

# %%
net = Net()
criterion = nn.BCEWithLogitsLoss()

optimizer = optim.Adam(net.parameters(), lr=1e-3)

# %%
metrics = [BCLogitMetric()]

# %%
print("Original dropout rate = %.2f" % net.rnn.first_layer.p_logit.sigmoid().item())
# Out:
# Original dropout rate = 0.51

# %%
# %%time
net = train_model(net, train_dl, val_dl, criterion, optimizer, "occupancy-concrete.pt", 100, metrics=metrics, patience=5)
# Out:
# [1, 100.00%] train loss: 0.679064
# [1, 100.00%] validate loss: 0.591887
# Accuracy = 0.903
# [2, 100.00%] train loss: 0.393983
# [2, 100.00%] validate loss: 0.270991
# Accuracy = 0.904
# [3, 100.00%] train loss: 0.256564
# [3, 100.00%] validate loss: 0.240446
# Accuracy = 0.902
# [4, 100.00%] train loss: 0.223226
# [4, 100.00%] validate loss: 0.208771
# Accuracy = 0.906
# [5, 100.00%] train loss: 0.198522
# [5, 100.00%] validate loss: 0.173306
# Accuracy = 0.913
# [6, 100.00%] train loss: 0.176920
# [6, 100.00%] validate loss: 0.165605
# Accuracy = 0.917
# [7, 100.00%] train loss: 0.154461
# [7, 100.00%] validate loss: 0.137551
# Accuracy = 0.922
# [8, 100.00%] train loss: 0.143173
# [8, 100.00%] validate loss: 0.130799
# Accuracy = 0.926
# [9, 100.00%] train loss: 0.131239
# [9, 100.00%] validate loss: 0.118968
# Accuracy = 0.930
# [10, 100.00%] train loss: 0.122220
# [10, 100.00%] validate loss: 0.118477
# Accuracy = 0.933
# [11, 100.00%] train loss: 0.116262
# [11, 100.00%] validate loss: 0.117644
# Accuracy = 0.936
# [12, 100.00%] train loss: 0.103082
# [12, 100.00%] validate loss: 0.119881
# Accuracy = 0.938
# Retry 1/5
# [13, 100.00%] train loss: 0.105523
# [13, 100.00%] validate loss: 0.098790
# Accuracy = 0.941
# [14, 100.00%] train loss: 0.108554
# [14, 100.00%] validate loss: 0.102102
# Accuracy = 0.943
# Retry 1/5
# [15, 100.00%] train loss: 0.096127
# [15, 100.00%] validate loss: 0.098250
# Accuracy = 0.945
# [16, 100.00%] train loss: 0.099035
# [16, 100.00%] validate loss: 0.090281
# Accuracy = 0.947
# [17, 100.00%] train loss: 0.087311
# [17, 100.00%] validate loss: 0.088298
# Accuracy = 0.948
# [18, 100.00%] train loss: 0.091616
# [18, 100.00%] validate loss: 0.090623
# Accuracy = 0.950
# Retry 1/5
# [19, 100.00%] train loss: 0.085783
# [19, 100.00%] validate loss: 0.088599
# Accuracy = 0.951
# Retry 2/5
# [20, 100.00%] train loss: 0.086312
# [20, 100.00%] validate loss: 0.097551
# Accuracy = 0.952
# Retry 3/5
# [21, 100.00%] train loss: 0.089740
# [21, 100.00%] validate loss: 0.101353
# Accuracy = 0.953
# Retry 4/5
# [22, 100.00%] train loss: 0.084405
# [22, 100.00%] validate loss: 0.087356
# Accuracy = 0.954
# [23, 100.00%] train loss: 0.081501
# [23, 100.00%] validate loss: 0.079335
# Accuracy = 0.956
# [24, 100.00%] train loss: 0.080588
# [24, 100.00%] validate loss: 0.078454
# Accuracy = 0.956
# [25, 100.00%] train loss: 0.072976
# [25, 100.00%] validate loss: 0.076659
# Accuracy = 0.957
# [26, 100.00%] train loss: 0.076882
# [26, 100.00%] validate loss: 0.085777
# Accuracy = 0.958
# Retry 1/5
# [27, 100.00%] train loss: 0.074807
# [27, 100.00%] validate loss: 0.082100
# Accuracy = 0.959
# Retry 2/5
# [28, 100.00%] train loss: 0.080665
# [28, 100.00%] validate loss: 0.083994
# Accuracy = 0.959
# Retry 3/5
# [29, 100.00%] train loss: 0.077806
# [29, 100.00%] validate loss: 0.073037
# Accuracy = 0.960
# [30, 100.00%] train loss: 0.079090
# [30, 100.00%] validate loss: 0.069354
# Accuracy = 0.961
# [31, 100.00%] train loss: 0.069084
# [31, 100.00%] validate loss: 0.072374
# Accuracy = 0.961
# Retry 1/5
# [32, 100.00%] train loss: 0.064973
# [32, 100.00%] validate loss: 0.067098
# Accuracy = 0.962
# [33, 100.00%] train loss: 0.071143
# [33, 100.00%] validate loss: 0.076620
# Accuracy = 0.963
# Retry 1/5
# [34, 100.00%] train loss: 0.069573
# [34, 100.00%] validate loss: 0.065279
# Accuracy = 0.963
# [35, 100.00%] train loss: 0.067932
# [35, 100.00%] validate loss: 0.073875
# Accuracy = 0.964
# Retry 1/5
# [36, 100.00%] train loss: 0.071751
# [36, 100.00%] validate loss: 0.064247
# Accuracy = 0.964
# [37, 100.00%] train loss: 0.068359
# [37, 100.00%] validate loss: 0.066414
# Accuracy = 0.965
# Retry 1/5
# [38, 100.00%] train loss: 0.066544
# [38, 100.00%] validate loss: 0.065822
# Accuracy = 0.965
# Retry 2/5
# [39, 100.00%] train loss: 0.067351
# [39, 100.00%] validate loss: 0.069748
# Accuracy = 0.966
# Retry 3/5
# [40, 100.00%] train loss: 0.061682
# [40, 100.00%] validate loss: 0.072690
# Accuracy = 0.966
# Retry 4/5
# [41, 100.00%] train loss: 0.066501
# [41, 100.00%] validate loss: 0.064713
# Accuracy = 0.966
# Retry 5/5
# CPU times: user 43.3 s, sys: 6.57 s, total: 49.9 s
# Wall time: 1min 2s

# %%
print("Optimized dropout rate = %.2f" % net.rnn.first_layer.p_logit.sigmoid().item())
# Out:
# Optimized dropout rate = 0.33

# %% [markdown]
# ## Test

# %%
test_table = pd.read_csv("./data/occupancy_data/datatest.txt")
test_table = test_table.drop("date", axis=1)
test_table = test_table.astype(np.float32)

# %%
X_test = test_table.drop("Occupancy", axis=1).values
X_test = scaler.transform(X_test)
X_test = np.array([X_test[i:i+SEQ_LEN, :] for i in range(0, len(X_test) - SEQ_LEN)])
X_test = X_test.swapaxes(1, 0)
Y_test = test_table["Occupancy"].values[SEQ_LEN:]
X_test = torch.tensor(X_test)

# %%
net.eval()
with torch.no_grad():
    outputs = net.sample(10, X_test)
    outputs = torch.sigmoid(outputs)
    uncertainties = uncertainty_avg(outputs)
    predictions = score_avg(outputs)

# %%
roc_auc_score(Y_test, predictions)
# Out:
# 0.9874536613136029

# %%
accuracy_score(Y_test, torch.round(predictions))
# Out:
# 0.9676691729323308

# %%
precision_score(Y_test, torch.round(predictions))
# Out:
# 0.9231508165225745

# %%
dist = torch.abs(predictions - Y_test)
A = aleatoric_uncertainty(outputs)
E = epistemic_uncertainty(outputs)

sns.scatterplot(x=dist, y=uncertainties)
sns.scatterplot(x=dist, y=A)
sns.scatterplot(x=dist, y=E)
plt.xlabel("dist")
plt.ylabel("uncertainty")
plt.legend(labels=['uncertainty', 'aleatoric', 'epistemic'])

# %% [markdown]
# ### Spread analysis for misclassification

# %%
T, B = outputs.shape[0:2]
post_sigmoid_df = pd.DataFrame(columns=["entry","value"])
for i in range(T):
    for j, idx in enumerate(dist.argsort()[-20:]):
        post_sigmoid_df.loc[i*B + j] = (j+1, outputs[i,idx])

plot = sns.catplot(x="entry", y="value", data=post_sigmoid_df)
plot.fig.set_figwidth(12)

# %% [markdown]
# ### Spread analysis for correct classification

# %%
T, B = outputs.shape[0:2]
post_sigmoid_df = pd.DataFrame(columns=["entry","value"])
for i in range(T):
    for j, idx in enumerate(dist.argsort()[:20]):
        post_sigmoid_df.loc[i*B + j] = (j+1, outputs[i,idx])

plot = sns.catplot(x="entry", y="value", data=post_sigmoid_df)
plot.fig.set_figwidth(12)
