# %%
import math
import numpy as np
import pandas as pd
import pandas_datareader as web
# Out:
# /usr/local/miniconda3/envs/mimic3/lib/python3.6/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %matplotlib inline

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch import optim
from stochastic_rnn import StochasticLSTM
from variational_module import MCDualMixin
from regression_uncertainty_utils import aleatoric_uncertainty, epistemic_uncertainty, prediction_avg, uncertainty
from train_utils import train_model

# %%
np.random.seed(4321)
torch.manual_seed(4321)

# %%
df = web.DataReader('AAPL', data_source='yahoo', start='2012-01-01', end='2019-12-17').astype(np.float32)
df.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2012-01-03  58.928570  58.428570  58.485714  58.747143  75555200.0  50.857235
# 2012-01-04  59.240002  58.468571  58.571430  59.062859  65005500.0  51.130558
# 2012-01-05  59.792858  58.952858  59.278572  59.718571  67817400.0  51.698215
# 2012-01-06  60.392857  59.888573  59.967144  60.342857  79573200.0  52.238651
# 2012-01-09  61.107143  60.192856  60.785713  60.247143  98506096.0  52.155792

# %%
plt.figure(figsize=(16, 8))
plt.title("Close Price History")
plt.plot(df["Close"])
plt.xlabel("Date", fontsize=18)
plt.ylabel("Close Price USD ($)", fontsize=18)
plt.show()

# %%
data = df.filter(["Close"])
dataset = data.values
training_data_len = math.ceil(len(dataset) * .8)

training_data_len
# Out:
# 1603

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.01316509],
#        [0.01457062],
#        [0.01748985],
#        ...,
#        [0.97658265],
#        [0.99755144],
#        [1.0000001 ]], dtype=float32)

# %%
STEP = 60

# %%
train_data = scaled_data[0:training_data_len, :]

x_train = np.array([train_data[i-STEP:i, 0] for i in range(STEP, training_data_len)])
y_train = np.array([train_data[i, 0] for i in range(STEP, training_data_len)])

# %%
ENTRY_COUNT = len(y_train)

# %%
x_train = x_train.reshape(ENTRY_COUNT, STEP, 1)
x_train.shape
# Out:
# (1543, 60, 1)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.3, random_state=42)
train_dl = torch.utils.data.DataLoader([(x_train[i], y_train[i]) for i in range(len(y_train))], shuffle=True, batch_size=50)
val_dl = torch.utils.data.DataLoader([(x_val[i], y_val[i]) for i in range(len(y_val))], shuffle=True, batch_size=50)

# %%
class Net(nn.Module, MCDualMixin):
    def __init__(self):
        super(Net, self).__init__()
        self.rnn = StochasticLSTM(1, 50, num_layers=1)
        self.fc1 = nn.Linear(50, 25)
        self.fc_mean = nn.Linear(25, 1)
        self.fc_log_var = nn.Linear(25, 1)
    
    def regularizer(self):        
        # Weight and bias regularizer
        weight_sum, bias_sum, dropout_reg = self.rnn.regularizer()
        
        return weight_sum + bias_sum + dropout_reg
    
    def get_output_shape(self, x):
        B = x.shape[1]
        return (B,1), (B,1)

    def forward(self, x):
        result, _ = self.rnn(x)
        result = torch.tanh(result[-1,:])
        result = torch.relu(self.fc1(result))
        mean = self.fc_mean(result)
        log_var = self.fc_log_var(result)
        return mean, log_var

# %%
net = Net()
def criterion(output, y):
    mean, log_var = output
    return 0.5 * torch.mean(torch.exp(-log_var) * (mean-y.view(-1,1))**2 + log_var)
    #return torch.mean((mean - y.view(-1,1))**2)

optimizer = optim.Adam(net.parameters(), lr=1e-3)

# %%
print("Original dropout rate = %.2f" % net.rnn.first_layer.p_logit.sigmoid().item())
# Out:
# Original dropout rate = 0.68

# %%
# %%time
net = train_model(net, train_dl, val_dl, criterion, optimizer, "stock-concrete.pt", 100, metrics=[], patience=6)
# Out:
# [1, 100.00%] train loss: -0.098526
# [1, 100.00%] validate loss: -0.215763
# [2, 100.00%] train loss: -0.573213
# [2, 100.00%] validate loss: -1.170360
# [3, 100.00%] train loss: -1.350927
# [3, 100.00%] validate loss: -1.447330
# [4, 100.00%] train loss: -1.458226
# [4, 100.00%] validate loss: -1.545931
# [5, 100.00%] train loss: -1.456956
# [5, 100.00%] validate loss: -1.510897
# Retry 1/6
# [6, 100.00%] train loss: -1.468405
# [6, 100.00%] validate loss: -1.498406
# Retry 2/6
# [7, 100.00%] train loss: -1.449095
# [7, 100.00%] validate loss: -1.541986
# Retry 3/6
# [8, 100.00%] train loss: -1.467459
# [8, 100.00%] validate loss: -1.484452
# Retry 4/6
# [9, 100.00%] train loss: -1.468032
# [9, 100.00%] validate loss: -1.544661
# Retry 5/6
# [10, 100.00%] train loss: -1.489750
# [10, 100.00%] validate loss: -1.565241
# [11, 100.00%] train loss: -1.498287
# [11, 100.00%] validate loss: -1.547389
# Retry 1/6
# [12, 100.00%] train loss: -1.518303
# [12, 100.00%] validate loss: -1.576275
# [13, 100.00%] train loss: -1.519465
# [13, 100.00%] validate loss: -1.583044
# [14, 100.00%] train loss: -1.547473
# [14, 100.00%] validate loss: -1.640280
# [15, 100.00%] train loss: -1.576961
# [15, 100.00%] validate loss: -1.679719
# [16, 100.00%] train loss: -1.614285
# [16, 100.00%] validate loss: -1.733072
# [17, 100.00%] train loss: -1.690957
# [17, 100.00%] validate loss: -1.809038
# [18, 100.00%] train loss: -1.756796
# [18, 100.00%] validate loss: -1.954836
# [19, 100.00%] train loss: -1.860815
# [19, 100.00%] validate loss: -2.090795
# [20, 100.00%] train loss: -2.112921
# [20, 100.00%] validate loss: -2.350485
# [21, 100.00%] train loss: -2.209961
# [21, 100.00%] validate loss: -2.544566
# [22, 100.00%] train loss: -2.412193
# [22, 100.00%] validate loss: -2.743774
# [23, 100.00%] train loss: -2.653817
# [23, 100.00%] validate loss: -3.031405
# [24, 100.00%] train loss: -2.788870
# [24, 100.00%] validate loss: -3.206576
# [25, 100.00%] train loss: -2.990851
# [25, 100.00%] validate loss: -2.631505
# Retry 1/6
# [26, 100.00%] train loss: -2.989984
# [26, 100.00%] validate loss: -3.430145
# [27, 100.00%] train loss: -3.243421
# [27, 100.00%] validate loss: -3.673886
# [28, 100.00%] train loss: -3.538980
# [28, 100.00%] validate loss: -3.789553
# [29, 100.00%] train loss: -3.524654
# [29, 100.00%] validate loss: -3.583184
# Retry 1/6
# [30, 100.00%] train loss: -3.623794
# [30, 100.00%] validate loss: -4.038472
# [31, 100.00%] train loss: -3.711153
# [31, 100.00%] validate loss: -4.036836
# Retry 1/6
# [32, 100.00%] train loss: -3.738472
# [32, 100.00%] validate loss: -4.059887
# [33, 100.00%] train loss: -3.898696
# [33, 100.00%] validate loss: -4.190422
# [34, 100.00%] train loss: -3.616975
# [34, 100.00%] validate loss: -3.585013
# Retry 1/6
# [35, 100.00%] train loss: -3.729376
# [35, 100.00%] validate loss: -4.075412
# Retry 2/6
# [36, 100.00%] train loss: -3.935905
# [36, 100.00%] validate loss: -4.291665
# [37, 100.00%] train loss: -3.900210
# [37, 100.00%] validate loss: -4.267859
# Retry 1/6
# [38, 100.00%] train loss: -3.971564
# [38, 100.00%] validate loss: -4.337583
# [39, 100.00%] train loss: -4.031456
# [39, 100.00%] validate loss: -4.376086
# [40, 100.00%] train loss: -3.855440
# [40, 100.00%] validate loss: -4.259114
# Retry 1/6
# [41, 100.00%] train loss: -3.880594
# [41, 100.00%] validate loss: -4.291276
# Retry 2/6
# [42, 100.00%] train loss: -4.074809
# [42, 100.00%] validate loss: -4.275847
# Retry 3/6
# [43, 100.00%] train loss: -3.864649
# [43, 100.00%] validate loss: -4.228961
# Retry 4/6
# [44, 100.00%] train loss: -4.042726
# [44, 100.00%] validate loss: -4.364993
# Retry 5/6
# [45, 100.00%] train loss: -3.915756
# [45, 100.00%] validate loss: -4.343840
# Retry 6/6
# CPU times: user 3min 19s, sys: 10.4 s, total: 3min 30s
# Wall time: 2min 31s

# %%
print("Optimized dropout rate = %.2f" % net.rnn.first_layer.p_logit.sigmoid().item())
# Out:
# Optimized dropout rate = 0.45

# %%
test_data = scaled_data[training_data_len - 60:, :]
x_test = torch.tensor([test_data[i-60:i, 0] for i in range(60, len(test_data))])
y_test = dataset[training_data_len:,:]
x_test = x_test.reshape(len(x_test), STEP, 1)

# %%
net.eval()
with torch.no_grad():
    out_mean, out_log_var = net.sample(10, x_test.transpose(1, 0))
    A = aleatoric_uncertainty(out_log_var)
    E = epistemic_uncertainty(out_mean)
    uncertainties = uncertainty(out_mean, out_log_var)
    uncertainties = uncertainties.numpy()
    predictions = prediction_avg(out_mean)
    predictions = scaler.inverse_transform(predictions.numpy())

rmse = np.sqrt(np.mean((predictions-y_test)**2))
rmse
# Out:
# 10.621808

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
valid.insert(1,"Predictions",predictions)
valid.insert(2,"Uncertainties",uncertainties)

plt.figure(figsize=(16, 8))
plt.title("Model")
plt.xlabel("Date", fontsize=18)
plt.ylabel("Close Price USD ($)", fontsize=18)
plt.plot(train["Close"])
plt.plot(valid[["Close", "Predictions"]])
plt.legend(["Train", "Val", "Predictions"], loc="lower right")
plt.show()

# %%
sns.scatterplot(x=np.abs(predictions-y_test).flatten(), y=uncertainties.flatten())
plt.xlabel("Absolute error")
plt.ylabel("Uncertainty")
plt.title("Uncertainty against Error")
plt.show()
