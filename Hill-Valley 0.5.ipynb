# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch import optim
import numpy as np
import pandas as pd
from stochastic_rnn import StochasticLSTM
from variational_module import MCSingleMixin
from train_utils import train_model, BCLogitMetric

# %%
from sklearn.preprocessing import minmax_scale
from sklearn.model_selection import train_test_split

# %%
from classification_uncertainty_utils import aleatoric_uncertainty, epistemic_uncertainty, uncertainty_avg, score_avg

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
np.random.seed(1234)
torch.manual_seed(1234)

# %%
training_table = pd.read_table("./data/hill-valley/Hill_Valley_with_noise_Training.data", sep=',', dtype=np.float32)
testing_table = pd.read_table("./data/hill-valley/Hill_Valley_with_noise_Testing.data", sep=',', dtype=np.float32)

# %%
dim = 1
seq_length = 100
DROP = 0.5

# %%
x_train = minmax_scale(training_table.drop("class", axis=1).values, axis=1)
y_train = training_table["class"].values
x_test = minmax_scale(testing_table.drop("class", axis=1).values, axis=1)
y_test = testing_table["class"].values

x_train = np.expand_dims(x_train, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.3, random_state=42)

N = len(y_train)

train_dl = torch.utils.data.DataLoader(
        [(x_train[i], y_train[i]) for i in range(len(y_train))],
        batch_size=10,
        shuffle=True
)
val_dl = torch.utils.data.DataLoader(
        [(x_val[i], y_val[i]) for i in range(len(y_val))],
        batch_size=10,
        shuffle=False
)
test_dl = torch.utils.data.DataLoader(
        [(x_test[i], y_test[i]) for i in range(len(y_test))],
        batch_size=len(y_test),
        shuffle=False
)

# %%
class Net(nn.Module, MCSingleMixin):
    def __init__(self):
        super(Net, self).__init__()
        self.rnn = StochasticLSTM(1, 10, DROP)
        self.fc = nn.Linear(10, 1)

    def regularizer(self):        
        # Weight and bias regularizer
        weight_sum, bias_sum, dropout_reg = self.rnn.regularizer()
        
        return weight_sum + bias_sum + dropout_reg
    
    def get_output_shape(self, x: torch.Tensor):
        B = x.shape[1]
        return (B,)

    def forward(self, x: torch.Tensor):
        out, _ = self.rnn(x)
        out = out[-1]
        out = torch.tanh(out)
        out = self.fc(out).flatten()
        return out

# %%
net = Net()
criterion = nn.BCEWithLogitsLoss()

optimizer = optim.Adam(net.parameters(), lr=1e-3)

# %%
metrics = [BCLogitMetric()]

# %%
# %%time
net = train_model(net, train_dl, val_dl, criterion, optimizer, "hill-valley-0.5.pt", 100, metrics=metrics, patience=5)
# Out:
# [1, 100.00%] train loss: 0.699921
# [1, 100.00%] validate loss: 0.709414
# Accuracy = 0.516
# [2, 100.00%] train loss: 0.682686
# [2, 100.00%] validate loss: 0.684922
# Accuracy = 0.739
# [3, 100.00%] train loss: 0.630952
# [3, 100.00%] validate loss: 0.595579
# Accuracy = 0.819
# [4, 100.00%] train loss: 0.511881
# [4, 100.00%] validate loss: 0.486023
# Accuracy = 0.852
# [5, 100.00%] train loss: 0.428247
# [5, 100.00%] validate loss: 0.413370
# Accuracy = 0.873
# [6, 100.00%] train loss: 0.382670
# [6, 100.00%] validate loss: 0.377479
# Accuracy = 0.888
# [7, 100.00%] train loss: 0.341822
# [7, 100.00%] validate loss: 0.328880
# Accuracy = 0.899
# [8, 100.00%] train loss: 0.308980
# [8, 100.00%] validate loss: 0.254416
# Accuracy = 0.911
# [9, 100.00%] train loss: 0.272004
# [9, 100.00%] validate loss: 0.236025
# Accuracy = 0.921
# [10, 100.00%] train loss: 0.237028
# [10, 100.00%] validate loss: 0.230818
# Accuracy = 0.926
# [11, 100.00%] train loss: 0.219963
# [11, 100.00%] validate loss: 0.222746
# Accuracy = 0.931
# [12, 100.00%] train loss: 0.218605
# [12, 100.00%] validate loss: 0.206781
# Accuracy = 0.935
# [13, 100.00%] train loss: 0.180908
# [13, 100.00%] validate loss: 0.171690
# Accuracy = 0.938
# [14, 100.00%] train loss: 0.158350
# [14, 100.00%] validate loss: 0.138652
# Accuracy = 0.941
# [15, 100.00%] train loss: 0.159377
# [15, 100.00%] validate loss: 0.119209
# Accuracy = 0.944
# [16, 100.00%] train loss: 0.147456
# [16, 100.00%] validate loss: 0.132362
# Accuracy = 0.947
# Retry 1/5
# [17, 100.00%] train loss: 0.138820
# [17, 100.00%] validate loss: 0.160951
# Accuracy = 0.948
# Retry 2/5
# [18, 100.00%] train loss: 0.142177
# [18, 100.00%] validate loss: 0.105640
# Accuracy = 0.951
# [19, 100.00%] train loss: 0.116600
# [19, 100.00%] validate loss: 0.107696
# Accuracy = 0.953
# Retry 1/5
# [20, 100.00%] train loss: 0.104421
# [20, 100.00%] validate loss: 0.090425
# Accuracy = 0.955
# [21, 100.00%] train loss: 0.104700
# [21, 100.00%] validate loss: 0.071877
# Accuracy = 0.958
# [22, 100.00%] train loss: 0.105069
# [22, 100.00%] validate loss: 0.087937
# Accuracy = 0.959
# Retry 1/5
# [23, 100.00%] train loss: 0.072572
# [23, 100.00%] validate loss: 0.105761
# Accuracy = 0.960
# Retry 2/5
# [24, 100.00%] train loss: 0.079027
# [24, 100.00%] validate loss: 0.055141
# Accuracy = 0.962
# [25, 100.00%] train loss: 0.086332
# [25, 100.00%] validate loss: 0.081391
# Accuracy = 0.963
# Retry 1/5
# [26, 100.00%] train loss: 0.092957
# [26, 100.00%] validate loss: 0.074026
# Accuracy = 0.963
# Retry 2/5
# [27, 100.00%] train loss: 0.098755
# [27, 100.00%] validate loss: 0.104503
# Accuracy = 0.964
# Retry 3/5
# [28, 100.00%] train loss: 0.137836
# [28, 100.00%] validate loss: 0.099948
# Accuracy = 0.965
# Retry 4/5
# [29, 100.00%] train loss: 0.105058
# [29, 100.00%] validate loss: 0.085948
# Accuracy = 0.966
# Retry 5/5
# CPU times: user 1min 57s, sys: 1.3 s, total: 1min 59s
# Wall time: 2min 3s

# %% [markdown]
# ### Test

# %%
net.eval()
acc = 0.0
with torch.no_grad():
    for i, (x, y) in enumerate(test_dl):
        pre_sigmoids = net.sample(10, x.transpose(-2,-3))
        post_sigmoids = torch.sigmoid(pre_sigmoids)
        uncertainties = uncertainty_avg(post_sigmoids)
        scores = score_avg(post_sigmoids)
        predictions = torch.round(scores)
        acc += (y == predictions).sum().item()

acc /= len(test_dl.dataset)
print("Accuracy = %.2f%%" % (acc * 100))
# Out:
# Accuracy = 100.00%

# %%
A = aleatoric_uncertainty(post_sigmoids)
E = epistemic_uncertainty(post_sigmoids)

# %%
dist = torch.abs(y - scores)
sns.scatterplot(x=dist, y=uncertainties)
sns.scatterplot(x=dist, y=A)
sns.scatterplot(x=dist, y=E)
plt.xlabel("diff")
plt.ylabel("uncertainty")
plt.legend(labels=['uncertainty', 'aleatoric', 'epistemic'])

# %% [markdown]
# ### Spread pre and post sigmoid analysis

# %%
T, B = pre_sigmoids.shape
pre_sigmoid_df = pd.DataFrame(columns=["entry","value"])
post_sigmoid_df = pd.DataFrame(columns=["entry","value"])
for i in range(T):
    for j in range(20):
        pre_sigmoid_df.loc[i*B + j] = (j+1, pre_sigmoids[i,j])
        post_sigmoid_df.loc[i*B + j] = (j+1, post_sigmoids[i,j])

# %%
plot = sns.catplot(x="entry", y="value", data=pre_sigmoid_df)
plot.fig.set_figwidth(12)

# %%
plot = sns.catplot(x="entry", y="value", data=post_sigmoid_df)
plot.fig.set_figwidth(12)

# %% [markdown]
# ### Flat line test

# %%
new_x_test = minmax_scale(np.full((2, 100), 0., dtype=np.float32), axis=1)
new_x_test = np.expand_dims(new_x_test, axis=-1)
new_x_test = new_x_test.swapaxes(-2,-3)
new_x_test = torch.tensor(new_x_test)

net.eval()
with torch.no_grad():
    outputs = net.sample(10, new_x_test)
    outputs = torch.sigmoid(outputs)
    uncertainties = uncertainty_avg(outputs)
    scores = score_avg(outputs)

plt.plot(new_x_test[:,0])
plt.show()
print("predictions", scores)
print("uncertainties", uncertainties)
# Out:
# predictions tensor([0.9708, 0.9729])
# uncertainties tensor([0.0284, 0.0263])

# %% [markdown]
# ### Noise test

# %%
new_x_test = minmax_scale(np.random.randn(2, 100).astype(np.float32), axis=1)
new_x_test = np.expand_dims(new_x_test, axis=-1)
new_x_test = new_x_test.swapaxes(-2,-3)
new_x_test = torch.tensor(new_x_test)

net.eval()
with torch.no_grad():
    outputs = net.sample(10, new_x_test)
    outputs = torch.sigmoid(outputs)
    uncertainties = uncertainty_avg(outputs)
    scores = score_avg(outputs)

plt.plot(new_x_test[:,0])
plt.show()
print("predictions", scores)
print("uncertainties", uncertainties)
# Out:
# predictions tensor([0.4271, 0.4577])
# uncertainties tensor([0.2447, 0.2482])

# %% [markdown]
# ### Note
# In binary classification, the maximum uncertainty is 0.25 (need to verify this), and the minimum is 0.
