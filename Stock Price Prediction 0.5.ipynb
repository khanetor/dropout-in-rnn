# %%
import math
import numpy as np
import pandas as pd
import pandas_datareader as web
# Out:
# /usr/local/miniconda3/envs/mimic3/lib/python3.6/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %matplotlib inline

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch import optim
from stochastic_rnn import StochasticLSTM
from variational_module import MCDualMixin
from regression_uncertainty_utils import aleatoric_uncertainty, epistemic_uncertainty, prediction_avg, uncertainty
from train_utils import train_model

# %%
np.random.seed(4321)
torch.manual_seed(4321)

# %%
df = web.DataReader('AAPL', data_source='yahoo', start='2012-01-01', end='2019-12-17').astype(np.float32)
df.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2012-01-03  58.928570  58.428570  58.485714  58.747143  75555200.0  50.857235
# 2012-01-04  59.240002  58.468571  58.571430  59.062859  65005500.0  51.130558
# 2012-01-05  59.792858  58.952858  59.278572  59.718571  67817400.0  51.698215
# 2012-01-06  60.392857  59.888573  59.967144  60.342857  79573200.0  52.238651
# 2012-01-09  61.107143  60.192856  60.785713  60.247143  98506096.0  52.155792

# %%
plt.figure(figsize=(16, 8))
plt.title("Close Price History")
plt.plot(df["Close"])
plt.xlabel("Date", fontsize=18)
plt.ylabel("Close Price USD ($)", fontsize=18)
plt.show()

# %%
data = df.filter(["Close"])
dataset = data.values
training_data_len = math.ceil(len(dataset) * .8)

training_data_len
# Out:
# 1603

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)
scaled_data
# Out:
# array([[0.01316509],
#        [0.01457062],
#        [0.01748985],
#        ...,
#        [0.97658265],
#        [0.99755144],
#        [1.0000001 ]], dtype=float32)

# %%
STEP = 60

# %%
train_data = scaled_data[0:training_data_len, :]

x_train = np.array([train_data[i-STEP:i, 0] for i in range(STEP, training_data_len)])
y_train = np.array([train_data[i, 0] for i in range(STEP, training_data_len)])

# %%
ENTRY_COUNT = len(y_train)

# %%
x_train = x_train.reshape(ENTRY_COUNT, STEP, 1)
x_train.shape
# Out:
# (1543, 60, 1)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.3, random_state=42)
train_dl = torch.utils.data.DataLoader([(x_train[i], y_train[i]) for i in range(len(y_train))], shuffle=True, batch_size=50)
val_dl = torch.utils.data.DataLoader([(x_val[i], y_val[i]) for i in range(len(y_val))], shuffle=True, batch_size=50)

# %%
class Net(nn.Module, MCDualMixin):
    def __init__(self):
        super(Net, self).__init__()
        self.rnn = StochasticLSTM(1, 50, dropout=0.5, num_layers=1)
        self.fc1 = nn.Linear(50, 25)
        self.fc_mean = nn.Linear(25, 1)
        self.fc_log_var = nn.Linear(25, 1)
    
    def regularizer(self):        
        # Weight and bias regularizer
        weight_sum, bias_sum, dropout_reg = self.rnn.regularizer()
        
        return weight_sum + bias_sum + dropout_reg
    
    def get_output_shape(self, x):
        B = x.shape[1]
        return (B,1), (B,1)

    def forward(self, x):
        result, _ = self.rnn(x)
        result = result[-1,:]
        result = torch.relu(self.fc1(result))
        mean = self.fc_mean(result)
        log_var = self.fc_log_var(result)
        return mean, log_var

# %%
net = Net()
def criterion(output, y):
    mean, log_var = output
    return 0.5 * torch.mean(torch.exp(-log_var) * (mean-y.view(-1,1))**2 + log_var)
    #return torch.mean((mean - y.view(-1,1))**2)

optimizer = optim.Adam(net.parameters(), lr=1e-3)

# %%
# %%time
net = train_model(net, train_dl, val_dl, criterion, optimizer, "stock-0.5.pt", 100, metrics=[], patience=6)
# Out:
# [1, 100.00%] train loss: -0.013724
# [1, 100.00%] validate loss: -0.119672
# [2, 100.00%] train loss: -0.350881
# [2, 100.00%] validate loss: -0.792926
# [3, 100.00%] train loss: -1.218622
# [3, 100.00%] validate loss: -1.420729
# [4, 100.00%] train loss: -1.423532
# [4, 100.00%] validate loss: -1.516659
# [5, 100.00%] train loss: -1.442718
# [5, 100.00%] validate loss: -1.529602
# [6, 100.00%] train loss: -1.441504
# [6, 100.00%] validate loss: -1.460087
# Retry 1/6
# [7, 100.00%] train loss: -1.476571
# [7, 100.00%] validate loss: -1.515593
# Retry 2/6
# [8, 100.00%] train loss: -1.481288
# [8, 100.00%] validate loss: -1.559829
# [9, 100.00%] train loss: -1.481756
# [9, 100.00%] validate loss: -1.531821
# Retry 1/6
# [10, 100.00%] train loss: -1.504717
# [10, 100.00%] validate loss: -1.615595
# [11, 100.00%] train loss: -1.512901
# [11, 100.00%] validate loss: -1.567260
# Retry 1/6
# [12, 100.00%] train loss: -1.514554
# [12, 100.00%] validate loss: -1.605565
# Retry 2/6
# [13, 100.00%] train loss: -1.539570
# [13, 100.00%] validate loss: -1.670401
# [14, 100.00%] train loss: -1.559449
# [14, 100.00%] validate loss: -1.666999
# Retry 1/6
# [15, 100.00%] train loss: -1.657957
# [15, 100.00%] validate loss: -1.760765
# [16, 100.00%] train loss: -1.717754
# [16, 100.00%] validate loss: -1.858662
# [17, 100.00%] train loss: -1.884723
# [17, 100.00%] validate loss: -2.055301
# [18, 100.00%] train loss: -2.084634
# [18, 100.00%] validate loss: -2.304468
# [19, 100.00%] train loss: -2.322118
# [19, 100.00%] validate loss: -2.638572
# [20, 100.00%] train loss: -2.510450
# [20, 100.00%] validate loss: -2.609157
# Retry 1/6
# [21, 100.00%] train loss: -2.674789
# [21, 100.00%] validate loss: -3.064799
# [22, 100.00%] train loss: -2.674001
# [22, 100.00%] validate loss: -3.079704
# [23, 100.00%] train loss: -2.891236
# [23, 100.00%] validate loss: -3.193616
# [24, 100.00%] train loss: -3.049439
# [24, 100.00%] validate loss: -3.444107
# [25, 100.00%] train loss: -3.233443
# [25, 100.00%] validate loss: -3.232377
# Retry 1/6
# [26, 100.00%] train loss: -3.222874
# [26, 100.00%] validate loss: -3.399259
# Retry 2/6
# [27, 100.00%] train loss: -3.398829
# [27, 100.00%] validate loss: -3.758904
# [28, 100.00%] train loss: -3.552268
# [28, 100.00%] validate loss: -3.790090
# [29, 100.00%] train loss: -3.524301
# [29, 100.00%] validate loss: -3.255094
# Retry 1/6
# [30, 100.00%] train loss: -3.540309
# [30, 100.00%] validate loss: -3.785956
# Retry 2/6
# [31, 100.00%] train loss: -3.638659
# [31, 100.00%] validate loss: -3.898989
# [32, 100.00%] train loss: -3.598556
# [32, 100.00%] validate loss: -3.943767
# [33, 100.00%] train loss: -3.529446
# [33, 100.00%] validate loss: -3.622451
# Retry 1/6
# [34, 100.00%] train loss: -3.718125
# [34, 100.00%] validate loss: -3.987788
# [35, 100.00%] train loss: -3.815814
# [35, 100.00%] validate loss: -4.038739
# [36, 100.00%] train loss: -3.690167
# [36, 100.00%] validate loss: -3.981146
# Retry 1/6
# [37, 100.00%] train loss: -3.756191
# [37, 100.00%] validate loss: -4.163666
# [38, 100.00%] train loss: -3.889328
# [38, 100.00%] validate loss: -4.128175
# Retry 1/6
# [39, 100.00%] train loss: -3.904732
# [39, 100.00%] validate loss: -3.915198
# Retry 2/6
# [40, 100.00%] train loss: -3.907220
# [40, 100.00%] validate loss: -4.058755
# Retry 3/6
# [41, 100.00%] train loss: -3.915555
# [41, 100.00%] validate loss: -3.560825
# Retry 4/6
# [42, 100.00%] train loss: -3.758583
# [42, 100.00%] validate loss: -3.890535
# Retry 5/6
# [43, 100.00%] train loss: -3.935635
# [43, 100.00%] validate loss: -4.172357
# [44, 100.00%] train loss: -3.952847
# [44, 100.00%] validate loss: -4.097226
# Retry 1/6
# [45, 100.00%] train loss: -3.694335
# [45, 100.00%] validate loss: -4.149095
# Retry 2/6
# [46, 100.00%] train loss: -3.971671
# [46, 100.00%] validate loss: -4.268177
# [47, 100.00%] train loss: -4.017874
# [47, 100.00%] validate loss: -4.229713
# Retry 1/6
# [48, 100.00%] train loss: -3.911349
# [48, 100.00%] validate loss: -4.046911
# Retry 2/6
# [49, 100.00%] train loss: -3.905191
# [49, 100.00%] validate loss: -4.246181
# Retry 3/6
# [50, 100.00%] train loss: -4.025958
# [50, 100.00%] validate loss: -4.270732
# [51, 100.00%] train loss: -4.028386
# [51, 100.00%] validate loss: -4.208905
# Retry 1/6
# [52, 100.00%] train loss: -3.891914
# [52, 100.00%] validate loss: -4.216770
# Retry 2/6
# [53, 100.00%] train loss: -4.029258
# [53, 100.00%] validate loss: -4.219796
# Retry 3/6
# [54, 100.00%] train loss: -4.005759
# [54, 100.00%] validate loss: -4.197976
# Retry 4/6
# [55, 100.00%] train loss: -3.941914
# [55, 100.00%] validate loss: -4.283027
# [56, 100.00%] train loss: -4.074443
# [56, 100.00%] validate loss: -4.332702
# [57, 100.00%] train loss: -3.924525
# [57, 100.00%] validate loss: -4.274918
# Retry 1/6
# [58, 100.00%] train loss: -4.061070
# [58, 100.00%] validate loss: -4.329870
# Retry 2/6
# [59, 100.00%] train loss: -4.109783
# [59, 100.00%] validate loss: -4.260747
# Retry 3/6
# [60, 100.00%] train loss: -3.981717
# [60, 100.00%] validate loss: -3.924793
# Retry 4/6
# [61, 100.00%] train loss: -3.892980
# [61, 100.00%] validate loss: -4.311236
# Retry 5/6
# [62, 100.00%] train loss: -4.046401
# [62, 100.00%] validate loss: -4.394182
# [63, 100.00%] train loss: -4.036377
# [63, 100.00%] validate loss: -4.399926
# [64, 100.00%] train loss: -4.084434
# [64, 100.00%] validate loss: -4.413023
# [65, 100.00%] train loss: -4.036327
# [65, 100.00%] validate loss: -4.422319
# [66, 100.00%] train loss: -4.130205
# [66, 100.00%] validate loss: -4.365760
# Retry 1/6
# [67, 100.00%] train loss: -4.090890
# [67, 100.00%] validate loss: -4.288909
# Retry 2/6
# [68, 100.00%] train loss: -4.083261
# [68, 100.00%] validate loss: -4.307276
# Retry 3/6
# [69, 100.00%] train loss: -4.165637
# [69, 100.00%] validate loss: -4.234450
# Retry 4/6
# [70, 100.00%] train loss: -4.099087
# [70, 100.00%] validate loss: -4.271874
# Retry 5/6
# [71, 100.00%] train loss: -3.940357
# [71, 100.00%] validate loss: -4.247865
# Retry 6/6
# CPU times: user 5min 20s, sys: 13 s, total: 5min 33s
# Wall time: 6min 20s

# %%
test_data = scaled_data[training_data_len - 60:, :]
x_test = torch.tensor([test_data[i-60:i, 0] for i in range(60, len(test_data))])
y_test = dataset[training_data_len:,:]
x_test = x_test.reshape(len(x_test), STEP, 1)

# %%
net.eval()
with torch.no_grad():
    out_mean, out_log_var = net.sample(10, x_test.transpose(1, 0))
    A = aleatoric_uncertainty(out_log_var)
    E = epistemic_uncertainty(out_mean)
    uncertainties = uncertainty(out_mean, out_log_var)
    uncertainties = uncertainties.numpy()
    predictions = prediction_avg(out_mean)
    predictions = scaler.inverse_transform(predictions.numpy())

rmse = np.sqrt(np.mean((predictions-y_test)**2))
rmse
# Out:
# 6.474945

# %%
train = data[:training_data_len]
valid = data[training_data_len:]
valid.insert(1,"Predictions",predictions)
valid.insert(2,"Uncertainties",uncertainties)

plt.figure(figsize=(16, 8))
plt.title("Model")
plt.xlabel("Date", fontsize=18)
plt.ylabel("Close Price USD ($)", fontsize=18)
plt.plot(train["Close"])
plt.plot(valid[["Close", "Predictions"]])
plt.legend(["Train", "Val", "Predictions"], loc="lower right")
plt.show()

# %%
sns.scatterplot(x=np.abs(predictions-y_test).flatten(), y=uncertainties.flatten())
plt.xlabel("Absolute error")
plt.ylabel("Uncertainty")
plt.title("Uncertainty against Error")
plt.show()
